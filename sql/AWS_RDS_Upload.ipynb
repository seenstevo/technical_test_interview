# %%
import pandas as pd

# %%
tweets = pd.read_csv('tweets_sql.csv').rename(columns = {"Unnamed: 0": 'id'})
users = pd.read_csv('users_sql.csv').rename(columns = {"Unnamed: 0": 'id'})

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             175 non-null    int64
#  1   tweet_id       175 non-null    int64
#  2   tweet_text     175 non-null    object
#  3   tweet_date     175 non-null    object
#  4   user_id        175 non-null    int64
#  5   tweet_retweet  175 non-null    int64
#  6   tweet_reply    175 non-null    int64
#  7   tweet_like     175 non-null    int64
#  8   tweet_quote    175 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 12.4+ KB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             57 non-null     int64
#  1   user_id        57 non-null     int64
#  2   user_name      57 non-null     object
#  3   user_username  57 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.9+ KB

# %%
import pymysql

# %%
db = pymysql.connect(host = 'database-1.ccl50gywe0s6.us-east-2.rds.amazonaws.com',
                     user = 'admin',
                     password = 'adminjjs',
                     port = 3306,
                     cursorclass = pymysql.cursors.DictCursor)

cursor = db.cursor()

# %%
cursor.execute("DROP DATABASE TheBridge_Tech_Tweets")
cursor.connection.commit()

# %%
#Create database
create_db = '''CREATE DATABASE TheBridge_Tech_Tweets'''
cursor.execute(create_db)
cursor.connection.commit()

# %%
#Select database and create table
use_db = ''' USE TheBridge_Tech_Tweets'''
cursor.execute(use_db)

create_table = '''
CREATE TABLE users (
    id INT NOT NULL AUTO_INCREMENT,
    user_id VARCHAR(30),
    user_name TEXT,
    user_username TEXT,
    PRIMARY KEY (id),
    INDEX users_user_id_index (user_id)
)
'''
cursor.execute(create_table)
db.commit()

# %%
#Select database and create table
use_db = ''' USE TheBridge_Tech_Tweets'''
cursor.execute(use_db)

create_table = '''
CREATE TABLE tweets (
    id INT NOT NULL AUTO_INCREMENT,
    tweet_id VARCHAR(30),
    tweet_text TEXT,
    tweet_date TEXT,
    user_id VARCHAR(30),
    tweet_retweet INT,
    tweet_reply INT,
    tweet_like INT,
    tweet_quote INT,
    PRIMARY KEY (id),
    FOREIGN KEY (user_id) REFERENCES users(user_id),
    INDEX tweets_user_id_index (user_id)
    )
'''
cursor.execute(create_table)
db.commit()
db.close()

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://admin:adminjjs@database-1.ccl50gywe0s6.us-east-2.rds.amazonaws.com:3306/TheBridge_Tech_Tweets')

# %%
users.to_sql(name = 'users', con = engine, if_exists = 'append', index = False)
# Out:
# 57

# %%
tweets.to_sql(name = 'tweets', con = engine, if_exists = 'append', index = False)
# Out:
# 175

# %%
engine.dispose()

# %%
db = pymysql.connect(host = 'database-1.ccl50gywe0s6.us-east-2.rds.amazonaws.com',
                     user = 'admin',
                     password = 'adminjjs',
                     port = 3306,
                     database = 'TheBridge_Tech_Tweets',
                     cursorclass = pymysql.cursors.DictCursor)

cursor = db.cursor()

# %%
sql = '''SELECT * FROM tweets'''
cursor.execute(sql)
mi_lista = cursor.fetchall()
pd.DataFrame(mi_lista)
# Out:
#       id             tweet_id  \
# 0      1  1610652818234347521
# 1      2  1610606391445815297
# 2      3  1610581093119365121
# 3      4  1610236180309868544
# 4      5  1609931268921114627
# ..   ...                  ...
# 170  171  1612429007739396097
# 171  172  1612411945251905537
# 172  173  1612384123816910852
# 173  174  1611813891322908672
# 174  176  1611338908196913153
#
#                                             tweet_text  \
# 0    ¿Te interesa el diseño de #producto digital? V...
# 1    ¡Empezamos el año con una #masterclass de #uxu...
# 2    ¿Te planteas un futuro como diseñador #uxui?🎨\...
# 3    Echa un👀a la historia de Verónica, alumni del ...
# 4    🤝 @EDEMempresarios se alía con @TheBridge_Tech...
# ..                                                 ...
# 170  Ya tenemos confirmado el sitio donde haremos e...
# 171  ¿Quieres conocer nuestro campus de Madrid?\n\n...
# 172  ¿Quieres desarrollar tu carrera en el mundo di...
# ...

# %%
sql = '''SELECT * FROM users'''
cursor.execute(sql)
mi_lista = cursor.fetchall()
pd.DataFrame(mi_lista)
# Out:
#     id              user_id                                        user_name  \
# 0    1             10279282                                Jesús Pérez Serna
# 1    2           2402179123                           Jorge González Revilla
# 2    3  1162694149956603904                                       The Bridge
# 3    4   874916978665938945                                 Startup Valencia
# 4    5  1151510939105144834                              EDEM universitarios
# 5    6            570795448                                             EDEM
# 6    7           1128860148                                       Economía 3
# 7    8   799935450844631040                                MediterráneoPress
# 8    9   921670812637257728                                    VLC Tech City
# 9   10           1175646685                                    Valéncia News
# 10  11            402013017                               Radio Valencia SER
# ...
